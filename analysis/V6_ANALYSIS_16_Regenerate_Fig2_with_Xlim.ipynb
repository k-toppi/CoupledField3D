# %%
# ==============================================================================
# NOTEBOOK FILENAME: V6_ANALYSIS_16_Regenerate_Fig2_with_Xlim.ipynb
#
# DESCRIPTION:
# This utility script resolves Task D-11. It corrects a critical error in the
# x-axis range of Figure 2 (SR Test). It re-plots the data from the SR sweep,
# explicitly setting the x-axis limits to the correct range of [0.1, 0.4]
# to match the manuscript's description.
#
# AUTHOR: Gemini (as the next-generation AI assistant)
# DATE: 2025-08-22
# ==============================================================================

# --- Part 1: Setup and Library Imports ---
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files
import os

print("Setup complete. Libraries imported.")

# --- Part 2: Upload the source data file ---
print("\nPlease upload the data file from the SR sweep simulation:")
print("--> SR_Test_Sweep_Checkpoint.csv <--")

try:
    uploaded = files.upload()
    csv_filename = list(uploaded.keys())[0]
    print(f"Successfully uploaded '{csv_filename}'.")
    results_df = pd.read_csv(csv_filename)
except (ValueError, IndexError, FileNotFoundError):
    print("\n[ERROR] File upload was cancelled or failed. Please run the cell again to retry.")
    raise SystemExit

# --- Part 3: Data Processing and Selection ---
print("\nProcessing data...")

# Find the unique T values and select representative ones
unique_T = sorted(results_df['T'].unique())
T_low = unique_T[5]
T_mid = unique_T[15]
T_high = unique_T[25]

print(f"Selected representative T values for plotting: Low={T_low:.2f}, Mid={T_mid:.2f}, High={T_high:.2f}")

# Filter the DataFrame for these T values
df_low = results_df[np.isclose(results_df['T'], T_low)]
df_mid = results_df[np.isclose(results_df['T'], T_mid)]
df_high = results_df[np.isclose(results_df['T'], T_high)]

# --- Part 4: Plotting the Corrected Figure ---
print("Generating the corrected plot with correct x-axis limits...")

# --- Plotting settings ---
plt.style.use('default')
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Liberation Serif']
plt.rcParams['mathtext.fontset'] = 'dejavuserif'
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42
plt.rcParams['axes.labelsize'] = 12
plt.rcParams['xtick.labelsize'] = 10
plt.rcParams['ytick.labelsize'] = 10
plt.rcParams['legend.fontsize'] = 10
plt.rcParams['axes.grid'] = True
plt.rcParams['grid.linestyle'] = ':'

# --- Create the plot ---
fig, ax = plt.subplots(figsize=(7, 5))

# Plot data for each representative T
ax.errorbar(df_low['omega_drive'], df_low['mean_snr_db'], yerr=df_low['sem_snr_db'],
            fmt='o-', capsize=4, label=f'Low Noise (T ≈ {T_low:.2f})', alpha=0.8)
ax.errorbar(df_mid['omega_drive'], df_mid['mean_snr_db'], yerr=df_mid['sem_snr_db'],
            fmt='s-', capsize=4, label=f'Mid Noise (T ≈ {T_mid:.2f})', alpha=0.8)
ax.errorbar(df_high['omega_drive'], df_high['mean_snr_db'], yerr=df_high['sem_snr_db'],
            fmt='^-', capsize=4, label=f'High Noise (T ≈ {T_high:.2f})', alpha=0.8)

ax.axhline(y=0, color='k', linestyle='--', linewidth=1, label='SNR = 0 dB (Signal = Noise)')

# --- CRITICAL CORRECTION HERE ---
# Explicitly set the x-axis limits to the correct range.
ax.set_xlim(0.1, 0.4)
# --- END OF CORRECTION ---

# Set labels and limits
ax.set_xlabel('Driving Frequency ($\omega_{drive}$)')
ax.set_ylabel('Signal-to-Noise Ratio (SNR) [dB]')
ax.set_title('SR Test: No SNR Peak at Sub-Threshold Drive')
ax.legend()
ax.set_ylim(-5, 5)

plt.tight_layout()

# --- Save the corrected figure with a new, final filename ---
output_filename = "v6_fig02a_revised_SR_Test_LinePlot_corrected.pdf"
plt.savefig(output_filename, format='pdf', dpi=300, bbox_inches='tight')

print(f"Generated corrected plot file: {output_filename}")
plt.show()

# --- Part 5: Automatic Download ---
print(f"\nPreparing to download the corrected figure...")
files.download(output_filename)

print("\n--- FIGURE 2 REGENERATION TASK COMPLETE ---")# ==============================================================================
# NOTEBOOK FILENAME: V6_ANALYSIS_16_Regenerate_Fig2_with_Xlim.ipynb
#
# DESCRIPTION:
# This utility script resolves Task D-11. It corrects a critical error in the
# x-axis range of Figure 2 (SR Test). It re-plots the data from the SR sweep,
# explicitly setting the x-axis limits to the correct range of [0.1, 0.4]
# to match the manuscript's description.
#
# AUTHOR: Gemini (as the next-generation AI assistant)
# DATE: 2025-08-22
# ==============================================================================

# --- Part 1: Setup and Library Imports ---
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files
import os

print("Setup complete. Libraries imported.")

# --- Part 2: Upload the source data file ---
print("\nPlease upload the data file from the SR sweep simulation:")
print("--> SR_Test_Sweep_Checkpoint.csv <--")

try:
    uploaded = files.upload()
    csv_filename = list(uploaded.keys())[0]
    print(f"Successfully uploaded '{csv_filename}'.")
    results_df = pd.read_csv(csv_filename)
except (ValueError, IndexError, FileNotFoundError):
    print("\n[ERROR] File upload was cancelled or failed. Please run the cell again to retry.")
    raise SystemExit

# --- Part 3: Data Processing and Selection ---
print("\nProcessing data...")

# Find the unique T values and select representative ones
unique_T = sorted(results_df['T'].unique())
T_low = unique_T[5]
T_mid = unique_T[15]
T_high = unique_T[25]

print(f"Selected representative T values for plotting: Low={T_low:.2f}, Mid={T_mid:.2f}, High={T_high:.2f}")

# Filter the DataFrame for these T values
df_low = results_df[np.isclose(results_df['T'], T_low)]
df_mid = results_df[np.isclose(results_df['T'], T_mid)]
df_high = results_df[np.isclose(results_df['T'], T_high)]

# --- Part 4: Plotting the Corrected Figure ---
print("Generating the corrected plot with correct x-axis limits...")

# --- Plotting settings ---
plt.style.use('default')
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Liberation Serif']
plt.rcParams['mathtext.fontset'] = 'dejavuserif'
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42
plt.rcParams['axes.labelsize'] = 12
plt.rcParams['xtick.labelsize'] = 10
plt.rcParams['ytick.labelsize'] = 10
plt.rcParams['legend.fontsize'] = 10
plt.rcParams['axes.grid'] = True
plt.rcParams['grid.linestyle'] = ':'

# --- Create the plot ---
fig, ax = plt.subplots(figsize=(7, 5))

# Plot data for each representative T
ax.errorbar(df_low['omega_drive'], df_low['mean_snr_db'], yerr=df_low['sem_snr_db'],
            fmt='o-', capsize=4, label=f'Low Noise (T ≈ {T_low:.2f})', alpha=0.8)
ax.errorbar(df_mid['omega_drive'], df_mid['mean_snr_db'], yerr=df_mid['sem_snr_db'],
            fmt='s-', capsize=4, label=f'Mid Noise (T ≈ {T_mid:.2f})', alpha=0.8)
ax.errorbar(df_high['omega_drive'], df_high['mean_snr_db'], yerr=df_high['sem_snr_db'],
            fmt='^-', capsize=4, label=f'High Noise (T ≈ {T_high:.2f})', alpha=0.8)

ax.axhline(y=0, color='k', linestyle='--', linewidth=1, label='SNR = 0 dB (Signal = Noise)')

# --- CRITICAL CORRECTION HERE ---
# Explicitly set the x-axis limits to the correct range.
ax.set_xlim(0.1, 0.4)
# --- END OF CORRECTION ---

# Set labels and limits
ax.set_xlabel('Driving Frequency ($\omega_{drive}$)')
ax.set_ylabel('Signal-to-Noise Ratio (SNR) [dB]')
ax.set_title('SR Test: No SNR Peak at Sub-Threshold Drive')
ax.legend()
ax.set_ylim(-5, 5)

plt.tight_layout()

# --- Save the corrected figure with a new, final filename ---
output_filename = "v6_fig02a_revised_SR_Test_LinePlot_corrected.pdf"
plt.savefig(output_filename, format='pdf', dpi=300, bbox_inches='tight')

print(f"Generated corrected plot file: {output_filename}")
plt.show()

# --- Part 5: Automatic Download ---
print(f"\nPreparing to download the corrected figure...")
files.download(output_filename)

print("\n--- FIGURE 2 REGENERATION TASK COMPLETE ---")
# Out:
# <>:88: SyntaxWarning: invalid escape sequence '\o'
# <>:194: SyntaxWarning: invalid escape sequence '\o'
# <>:88: SyntaxWarning: invalid escape sequence '\o'
# <>:194: SyntaxWarning: invalid escape sequence '\o'
# /tmp/ipython-input-3150210268.py:88: SyntaxWarning: invalid escape sequence '\o'
#   ax.set_xlabel('Driving Frequency ($\omega_{drive}$)')
# /tmp/ipython-input-3150210268.py:194: SyntaxWarning: invalid escape sequence '\o'
#   ax.set_xlabel('Driving Frequency ($\omega_{drive}$)')
# Setup complete. Libraries imported.
#
# Please upload the data file from the SR sweep simulation:
# --> SR_Test_Sweep_Checkpoint.csv <--
#      <input type="file" id="files-382f4d92-1144-4816-bcab-ba67edf64a24" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-382f4d92-1144-4816-bcab-ba67edf64a24">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
# ...
